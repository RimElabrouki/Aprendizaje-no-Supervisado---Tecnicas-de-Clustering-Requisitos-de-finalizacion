# %% [markdown]
# ## Técnica de K-Means

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, precision_score, recall_score
from itertools import combinations
from sklearn.impute import SimpleImputer  # Importar SimpleImputer
from sklearn.preprocessing import MinMaxScaler  # Importar MinMaxScaler
import time

# Cargar datos
df_datos = pd.read_csv("datos/credit_risk_dataset.csv")

# Definir columnas importantes
columnas_importantes = ['person_age', 'person_income', 'loan_status', 'cb_person_cred_hist_length', 'loan_grade']

# Preprocesamiento de datos
imputer = SimpleImputer(strategy='mean')
df_datos[columnas_importantes] = imputer.fit_transform(df_datos[columnas_importantes])

# Normalizar los datos
arr_normalizado = MinMaxScaler().fit_transform(df_datos[columnas_importantes])

# Crear DataFrame con los datos normalizados
df_normalizado = pd.DataFrame(arr_normalizado, columns=columnas_importantes)

# Función para entrenar y evaluar modelo de K-Means
def train_evaluate_kmeans(X_train, X_test, y_train, y_test):
    start_model_generation = time.time()
    kmeans = KMeans(n_clusters=2, init='k-means++', random_state=42, n_init='auto') 
    kmeans.fit(X_train)
    end_model_generation = time.time()
    model_generation_time = end_model_generation - start_model_generation
    
    start_test_prediction = time.time()
    y_pred_train = kmeans.predict(X_train)
    y_pred_test = kmeans.predict(X_test)
    
    # Mapeo de clusters a valores objetivo
    cluster_0_label = np.argmax(np.bincount(y_train[y_pred_train == 0]))
    cluster_1_label = np.argmax(np.bincount(y_train[y_pred_train == 1]))
    y_pred_test_mapped = [cluster_0_label if pred == 0 else cluster_1_label for pred in y_pred_test]
    
    # Calcular métricas de validación
    accuracy = accuracy_score(y_test, y_pred_test_mapped)
    precision = precision_score(y_test, y_pred_test_mapped, average='weighted', zero_division=1)
    recall = recall_score(y_test, y_pred_test_mapped, average='weighted')
    end_test_prediction = time.time()
    test_prediction_time = end_test_prediction - start_test_prediction
    
    return accuracy, precision, recall, model_generation_time, test_prediction_time

# DataFrame para almacenar resultados
resultados = []

# Bucle para generar todas las combinaciones posibles de columnas
for r in range(1, len(columnas_importantes) + 1):
    combinaciones_columnas = combinations(columnas_importantes, r)
    # Generar combinaciones de longitud r
    for cols in combinaciones_columnas:
        cols = list(cols)
        X_train_subset = df_normalizado.loc[:, cols]  # Seleccionar las columnas de entrenamiento
        X_test_subset = df_normalizado.loc[:, cols]   # Seleccionar las columnas de prueba
        y_train_subset = df_datos['loan_status']  # Variable objetivo para entrenamiento
        y_test_subset = df_datos['loan_status']   # Variable objetivo para prueba
        
        # Dividir los datos en conjuntos de entrenamiento y prueba
        X_train, X_test, y_train, y_test = train_test_split(X_train_subset, y_train_subset, test_size=0.2, random_state=100)
        
        accuracy, precision, recall, model_generation_time, test_prediction_time = train_evaluate_kmeans(X_train, X_test, y_train, y_test)
        resultados.append([cols, accuracy, precision, recall, model_generation_time, test_prediction_time])

# Crear DataFrame final
df_resultados = pd.DataFrame(resultados, columns=['Columnas', 'Exactitud', 'Precisión', 'Sensibilidad', 'Tiempo_Modelo', 'Tiempo_Prueba'])

# Ordenar DataFrame por Exactitud
df_resultados = df_resultados.sort_values(by='Exactitud', ascending=False)

# Mostrar DataFrame final
for idx, row in df_resultados.iterrows():
    print("Combinación de Columnas: {}".format(row['Columnas']))
    print("Exactitud: {:.2f}".format(row['Exactitud']))
    print("Precisión: {:.2f}".format(row['Precisión']))
    print("Sensibilidad: {:.2f}".format(row['Sensibilidad']))
    print("Tiempo de Generación del Modelo: {:.6f} segundos".format(row['Tiempo_Modelo']))
    print("Tiempo de Prueba: {:.6f} segundos".format(row['Tiempo_Prueba']))
    print("---------------------------------------")
# Out:
# Combinación de Columnas: ['person_age', 'person_income', 'loan_status']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.036199 segundos
# Tiempo de Prueba: 0.094065 segundos
# ---------------------------------------
# Combinación de Columnas: ['loan_status', 'cb_person_cred_hist_length']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.034993 segundos
# Tiempo de Prueba: 0.077542 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_income', 'loan_status', 'cb_person_cred_hist_length', 'loan_grade']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.034001 segundos
# Tiempo de Prueba: 0.073526 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'loan_status', 'cb_person_cred_hist_length', 'loan_grade']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.034512 segundos
# Tiempo de Prueba: 0.071513 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'person_income', 'loan_status', 'loan_grade']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.034555 segundos
# Tiempo de Prueba: 0.069000 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'person_income', 'loan_status', 'cb_person_cred_hist_length']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.035005 segundos
# Tiempo de Prueba: 0.072515 segundos
# ---------------------------------------
# Combinación de Columnas: ['loan_status', 'cb_person_cred_hist_length', 'loan_grade']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.034988 segundos
# Tiempo de Prueba: 0.072521 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_income', 'loan_status', 'loan_grade']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.035001 segundos
# Tiempo de Prueba: 0.074534 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_income', 'loan_status', 'cb_person_cred_hist_length']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.035998 segundos
# Tiempo de Prueba: 0.070517 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'loan_status', 'loan_grade']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.034531 segundos
# Tiempo de Prueba: 0.072999 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'loan_status', 'cb_person_cred_hist_length']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.037010 segundos
# Tiempo de Prueba: 0.072521 segundos
# ---------------------------------------
# Combinación de Columnas: ['loan_status', 'loan_grade']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.034011 segundos
# Tiempo de Prueba: 0.074538 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'person_income', 'loan_status', 'cb_person_cred_hist_length', 'loan_grade']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.037003 segundos
# Tiempo de Prueba: 0.073539 segundos
# ---------------------------------------
# Combinación de Columnas: ['loan_status']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.031997 segundos
# Tiempo de Prueba: 0.076535 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_income', 'loan_status']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.036527 segundos
# Tiempo de Prueba: 0.072523 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'loan_status']
# Exactitud: 1.00
# Precisión: 1.00
# Sensibilidad: 1.00
# Tiempo de Generación del Modelo: 0.036006 segundos
# Tiempo de Prueba: 0.073528 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_income', 'loan_grade']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.037008 segundos
# Tiempo de Prueba: 0.075543 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_income', 'cb_person_cred_hist_length', 'loan_grade']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.039003 segundos
# Tiempo de Prueba: 0.073544 segundos
# ---------------------------------------
# Combinación de Columnas: ['cb_person_cred_hist_length']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.032998 segundos
# Tiempo de Prueba: 0.072542 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'person_income', 'cb_person_cred_hist_length', 'loan_grade']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.036530 segundos
# Tiempo de Prueba: 0.072003 segundos
# ---------------------------------------
# Combinación de Columnas: ['loan_grade']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.032002 segundos
# Tiempo de Prueba: 0.071524 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'person_income']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.039994 segundos
# Tiempo de Prueba: 0.076521 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'cb_person_cred_hist_length']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.035523 segundos
# Tiempo de Prueba: 0.069996 segundos
# ---------------------------------------
# Combinación de Columnas: ['cb_person_cred_hist_length', 'loan_grade']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.036549 segundos
# Tiempo de Prueba: 0.073255 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'loan_grade']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.034518 segundos
# Tiempo de Prueba: 0.070023 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'cb_person_cred_hist_length', 'loan_grade']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.035530 segundos
# Tiempo de Prueba: 0.075012 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_income', 'cb_person_cred_hist_length']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.035000 segundos
# Tiempo de Prueba: 0.075552 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'person_income', 'loan_grade']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.034995 segundos
# Tiempo de Prueba: 0.072514 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age', 'person_income', 'cb_person_cred_hist_length']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.038521 segundos
# Tiempo de Prueba: 0.073080 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_income']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.032503 segundos
# Tiempo de Prueba: 0.074017 segundos
# ---------------------------------------
# Combinación de Columnas: ['person_age']
# Exactitud: 0.78
# Precisión: 0.83
# Sensibilidad: 0.78
# Tiempo de Generación del Modelo: 0.072514 segundos
# Tiempo de Prueba: 0.076006 segundos
# ---------------------------------------
